# %%
import glob

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/train/*.p')

print len(files)

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/test/*.p')

print len(files)

# %%
# verifs

import numpy as np

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/train/*.p')

for f in files[:1]:
    print f
    test = pickle.load( open(f, 'rb'))
    
    scipy.io.wavfile.write(os.path.join(temp_path,'temp.wav'), 16000, (test*32768).astype(np.dtype('i2')))
    os.system('aplay ~/temp.wav')
    
    #librosa.output.write_wav( os.path.join(temp_path,'temp.wav'), test, sr=16000)
    
    print len(test)
    
    plt.plot(range(len(test)), test)
    plt.show()

# %% [markdown]
# # transfos one by one

# %%
##### up to rescale

import os 
import scipy.io

import pickle
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

import sillytalks.transform.pipeline
reload(sillytalks.transform.pipeline)

source_path = '/home/freinque/cours/voice/sillytalks/data/pickles/train/'
target_path = '/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/'
temp_path = '/home/freinque/'

sillytalks.transform.pipeline.full(source_path, target_path)


# verifs

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/*.p')

for f in files[:8]:
    print f
    test = pickle.load( open(f, 'rb'))
    
    scipy.io.wavfile.write(os.path.join(temp_path,'temp.wav'), 16000, (test*32768).astype(np.dtype('i2')))
    os.system('aplay ~/temp.wav')
    
    print len(test)
    
    plt.plot(range(len(test)), test)
    plt.show()

# %%
##### up to butter

import os 
import scipy.io

import pickle
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

import sillytalks.transform.pipeline
reload(sillytalks.transform.pipeline)

source_path = '/home/freinque/cours/voice/sillytalks/data/pickles/train/'
target_path = '/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/'
temp_path = '/home/freinque/'

sillytalks.transform.pipeline.full(source_path, target_path)


# verifs

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/*.p')

for f in files[:8]:
    print f
    test = pickle.load( open(f, 'rb'))
    
    scipy.io.wavfile.write(os.path.join(temp_path,'temp.wav'), 16000, (test*32768).astype(np.dtype('i2')))
    os.system('aplay ~/temp.wav')
    
    print len(test)
    
    plt.plot(range(len(test)), test)
    plt.show()

# %%
##### up to ft

import os 
import scipy.io

import pickle
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import sillytalks.transform.pipeline
reload(sillytalks.transform.pipeline)

source_path = '/home/freinque/cours/voice/sillytalks/data/pickles/train/'
target_path = '/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/'
temp_path = '/home/freinque/'

sillytalks.transform.pipeline.full(source_path, target_path)


# verifs

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/*.p')
#files = ['/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/off_c0445658_nohash_4.p',]

for f in files[:1]:
    print f
    test = pickle.load( open(f, 'rb'))
    
    print len(test)

    test.sum(axis=1).plot()
    plt.show()
    sns.heatmap(test.iloc[::5,:], xticklabels=False, yticklabels=True)
    plt.show()

# %%
import numpy as np
import pickle
import seaborn as sns
import matplotlib.pyplot as plt

import glob

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/train/*.p')
print len(files)
files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/*.p')
print len(files)

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/test/*.p')
print len(files)
files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/*.p')
print len(files)

# %%
##### up to ft

import os 
import scipy.io

import pickle
import glob
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

import sillytalks.transform.pipeline
reload(sillytalks.transform.pipeline)

source_path = '/home/freinque/cours/voice/sillytalks/data/pickles/test/'
target_path = '/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/'
temp_path = '/home/freinque/'

sillytalks.transform.pipeline.full(source_path, target_path)
# Out:
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_f3fa729cc.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_de0fb50a4.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_11c571110.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_52c238bb2.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_1c6e53321.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_b41e640f6.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_a5706811b.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_114d9205a.p
# saved_path : /home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/test_clip_55f717d64.p
# ...

# %%
# verifs

files = glob.glob('/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_test/*.p')
#files = ['/home/freinque/cours/voice/sillytalks/data/pickles/pipeline_train/off_c0445658_nohash_4.p',]

for f in files[:10]:
    print f
    test = pickle.load( open(f, 'rb'))
    
    print len(test)

    test.sum(axis=1).plot()
    plt.show()
    sns.heatmap(test, xticklabels=False, yticklabels=True)
    plt.show()
